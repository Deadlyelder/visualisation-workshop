# %% [markdown]
# ## Matplotlib

# %% [markdown]
# Matplotlib is a one of the most famous library for creating static, animated, and interactive visualizations in Python. It has been highly used

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Understanding a typical figure in any generated plot

# %% [markdown]
# Setting the parameters for a plot. The important things about plotting using pyplot (matplotlib) is displaying the data, stacking graphs on the pyplot object and drawing a basic figure around the graph.

# %% [markdown]
# It is important to set the co-ordinates and then using the plot function map the co-ordinates. Finally, a simple  `show()`  to display the plotted graph.
# *Note:* the plot function, by default will also trigger the show function in newwer versions of the matplotlib.

# %%
X = range(100)
Y = range(100)

# %%
plt.plot(X, Y)

# %%
plt.show()

# %% [markdown]
# ## Figures, Axes and Plots

# %%
X_1 = range(100)
Y_1 = [np.cos(value) for value in X]

# %%
X_2 = range(100)
Y_2 = [np.sin(value) for value in X]

# %%
plt.plot(X_1, Y_1)

# %%
plt.plot(X_2, Y_2)

# %% [markdown]
# The earlier example shows us two different graph plots for the sin and cos, to map them on the same plot, all we have to do is run our functions as one :)

# %%
plt.plot(X_1, Y_1)
plt.plot(X_2, Y_2)
plt.show()

# %% [markdown]
# ## Figures, Axes and Plot B

# %%
fig = plt.figure()  # Sets our plot as a figure
fig.set_size_inches(10, 5)  # we set the size of our figure

ax_1 = fig.add_subplot(1, 2, 1)  # We use the subplot to set our first plot
ax_2 = fig.add_subplot(1, 2, 2)  # Second subplot

ax_1.plot(X_1, Y_1, c="b")  #  Our first plot
ax_2.plot(X_2, Y_2, c="g")  # Second plot
plt.show()

# %% [markdown]
# The `c` is shorthand for the parameter argument for color with the b and g being shorthand for the standard colors.

# %% [markdown]
# ## Set Color

# %% [markdown]
# Lets have a further look on colors namely, how to use the color property that was breifly mentioned earlier, the shorthands for the colors and the predefined color.
# For further information on setting the colors and patters, refer to the [Colors API](http://matplotlib.org/2.0.2/api/colors_api.html).

# %%
X_1 = range(100)
Y_1 = [value for value in X_1]

X_2 = range(100)
Y_2 = [value + 100 for value in X_2]

# %%
plt.plot(X_1, Y_1, color="#2EFE2E")
plt.plot(X_2, Y_2, color="r")
plt.show()

# %% [markdown]
# When presenting the plots, you can also set the style of the lines within the plot to be dotted or dashed.

# %%
plt.plot(X_1, Y_1, c="b", linestyle="dashed")  # c = color
plt.plot(X_2, Y_2, c="r", ls="dotted")
plt.show()

# %% [markdown]
# ## Legends
# Any graph or plotted figure is uless without a proper set of legengs to indicate the data and its meaning.

# %%
# Our example
X_1 = range(100)
Y_1 = [value for value in X_1]

X_2 = range(100)
Y_2 = [value + 100 for value in X_2]

# %%
plt.plot(X_1, Y_1, color="b", linestyle="dashed")
plt.plot(X_2, Y_2, color="r", linestyle="dotted")

plt.title("Two lines") # A simple title
plt.show()

# %% [markdown]
# In academia, LaTeX has been used heavily to represent papers, specifically mathematical expressions. Plots in many sense are representation of mathematical expression as such being able to plot latex within the plot serves the best.
# Mathplotlib allow syou to represent LaTex within the plots with realive ace.

# %%
plt.title('$y = \\frac{ax + b}{b^2}$') # Simply write the LaTeX as they normally would be
plt.show()

# %% [markdown]
# Another important point is to provide index for each of the axis, which is similar to putting on the title.

# %%
plt.title('$y = ax+b$')
plt.xlabel('$x_line$')
plt.ylabel('y_line')

plt.show()
