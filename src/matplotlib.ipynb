# %% [markdown]
# ## Matplotlib

# %% [markdown]
# Matplotlib is one of the most famous libraries for creating static, animated, and interactive visualizations in Python. It has been highly used in academia and industry for different visual representations of the data.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Understanding a familiar figure in any generated plot is crucial towards the correct interpretation of the data it represents.
# The figure below represents an ideal plot with all its components.
# The figure is taken from the official matplolib homepage.

# %% [markdown]
# ![elements_of_figure.png](data:image/png;base64,...)

# %% [markdown]
# The essential things about plotting using pyplot (matplotlib) are displaying the data, stacking graphs on the pyplot object, and drawing a necessary figure around the chart.

# %% [markdown]
# It is essential to set the coordinates and then map the coordinates using the plot function. Finally, a simple  `show()` displays the plotted graph.
# *Note:* the plot function, by default, will also trigger the show function in newer versions of the matplotlib. Although if you are stacking multiple call functions to plot, its better to use it :)

# %%
X = range(100)
Y = range(100)

# %%
plt.plot(X, Y)

# %% [markdown]
# ## Figures, Axes and Plots

# %%
X_1 = range(100)
Y_1 = [np.cos(value) for value in X]

# %%
X_2 = range(100)
Y_2 = [np.sin(value) for value in X]

# %%
plt.plot(X_1, Y_1)

# %%
plt.plot(X_2, Y_2)

# %% [markdown]
# The earlier example shows us two different graph plots for the sin and cos. To map them on the same plot, all we have to do is run our functions as one :)

# %%
plt.plot(X_1, Y_1)
plt.plot(X_2, Y_2)
plt.show()

# %% [markdown]
# ## Figures, Axes and Plot B

# %%
fig = plt.figure()  # Sets our plot as a figure
fig.set_size_inches(10, 5)  # we set the size of our figure

ax_1 = fig.add_subplot(1, 2, 1)  # We use the subplot to set our first plot
ax_2 = fig.add_subplot(1, 2, 2)  # Second subplot

ax_1.plot(X_1, Y_1, c="b")  #  Our first plot
ax_2.plot(X_2, Y_2, c="g")  # Second plot
plt.show()

# %% [markdown]
# The `c` is shorthand for the parameter argument for color, with the b and g being shorthand for the standard colors.

# %% [markdown]
# ## Set Color

# %% [markdown]
# Let’s have a different look at colors, namely, how to use the color property that was briefly mentioned earlier, the shorthands for the colors, and the predefined color.
# For further information on setting the colors and patterns, refer to the [Colors API](http://matplotlib.org/2.0.2/api/colors_api.html).

# %%
X_1 = range(100)
Y_1 = [value for value in X_1]

X_2 = range(100)
Y_2 = [value + 100 for value in X_2]

# %%
plt.plot(X_1, Y_1, color="#2EFE2E")
plt.plot(X_2, Y_2, color="r")
plt.show()

# %% [markdown]
# When presenting the plots, you can also set the style of the lines within the plot to be dotted or dashed.

# %%
plt.plot(X_1, Y_1, c="b", linestyle="dashed")  # c = color
plt.plot(X_2, Y_2, c="r", ls="dotted")
plt.show()

# %% [markdown]
# ## Legends
# Any graph or plotted figure is useless without proper legends to indicate the data and its meaning.

# %%
# Our example
X_1 = range(100)
Y_1 = [value for value in X_1]

X_2 = range(100)
Y_2 = [value + 100 for value in X_2]

# %%
plt.plot(X_1, Y_1, color="b", linestyle="dashed")
plt.plot(X_2, Y_2, color="r", linestyle="dotted")

plt.title("A simple plot of two lines") # A simple title
plt.show()

# %% [markdown]
# LaTeX has been used heavily to represent papers, specifically mathematical expressions in academia. Plots, in many senses, are representations of mathematical expression. They can plot latex within the plot that serves the best.
# Mathplotlib allows you to represent LaTeX within the plots with realive ace.

# %%
# Simply write the LaTeX as they normally would be
plt.title('$y = \\frac{ax + b}{b^2}$') 
plt.show()

# %% [markdown]
# Another important point is to provide a legend index for each axis, which is similar to putting on the title.

# %%
plt.title('$y = ax+b$')
plt.xlabel('$x_{line}$')
plt.ylabel('y_line')

plt.show()

# %% [markdown]
# Providing a more accessible read on the graphs and their plotted data is easier to convey information.

# %%
plt.plot(X_1, Y_1, color="b", linestyle="dashed", label='blue dashed line')
plt.plot(X_2, Y_2, color="r", linestyle="dotted", label='red dotted line')

# loc provides the location of the legend box in the plot
plt.legend(shadow=True, fancybox=True, loc="upper right")

plt.title('$y = ax+b$')
plt.xlabel('x_line')
plt.ylabel('y_line')

plt.show()

# %% [markdown]
# Similarly, it is useful to plot the graph with grid lines
# to read and understand the data points within the graph.

# %%
plt.plot(X_1, Y_1, color="b", linestyle="dashed", label='line_1')
plt.plot(X_2, Y_2, color="r", linestyle="dotted", label='line_2')
plt.legend(shadow=True, fancybox=True, loc="lower right")

plt.grid(True, lw=0.4, ls="--", c=".90")
plt.xlim(-100, 200)
plt.ylim(-200, 200)

plt.title('$y = ax+b$')
plt.xlabel('$x_{line}$')
plt.ylabel('y_line')

plt.show()

# %% [markdown]
# ## Different types of graph
# A graph can be represented in different forms, each of which can be used in a specific context.

# %% [markdown]
# ### Scatter graph
#
# * A scatter plot is also known as scatter chart or scatter graph
# * Uses dots to represent values for two different numeric variables
# * The position of each dot on the horizontal and vertical axis indicates values
# * Typically, scatter plots are used to observe relationships between variables.

# %%
# random samples within a uniform distribution over [0, 1)
data_1 = np.random.rand(512, 2)
data_2 = np.random.rand(512, 2)

# %%
# We can switch the markers to different types
plt.scatter(data_1[:, 0], data_1[:, 1], c="b", marker="o")
plt.scatter(data_2[:, 0], data_2[:, 1], c="r", marker="x")
plt.title('Scatter plot')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.show()

# %% [markdown]
# The size of the area of the data point can be controlled.

# %%
N = 50

x = np.random.rand(N)
y = np.random.rand(N)

area = np.pi * (15 * np.random.rand(N))**2
colors = np.random.rand(N)

# Specify the size of the data compared to the size
plt.scatter(x, y, s=area, c=colors, alpha=0.5) 
plt.title('Scatter Area plot')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.show()

# %% [markdown]
# ### Bar Chart
# * Also known as a bar plot
# * Represents the category of data as rectangular bars
# * The lengths and height are proportional to the values in the dataset

# %%
# We use arbitary data here
data = [[5., 25., 50., 20.], [4., 23., 51., 17], [6., 22., 52., 19]]
X = np.arange(0, 8, 2)  # [0 2 4 6]

# %%
plt.bar(X + 0.5, data[0], color='b', width=0.5)
plt.bar(X + 0.0, data[1], color='g', width=0.5)
plt.bar(X + 1.0, data[2], color='r', width=0.5)
plt.xticks(X + 0.5, ("A", "B", "C", "D"))
plt.title('Bar Chart')
plt.xlabel('Category')
plt.ylabel('Length')
plt.show()

# %% [markdown]
# ### Stacked Bar Graph

# %%
data = np.array([[5., 25., 50., 20.], [4., 23., 51., 17], [6., 22., 52., 19]])
color_list = ['b', 'g', 'r']
data_label = ["A", "B", "C"]
X = np.arange(data.shape[1])

# %%
for i in range(data.shape[0]):
    plt.bar(X,
            data[i],
            bottom=np.sum(data[:i], axis=0),
            color=color_list[i],
            label=data_label[i])
plt.legend()
plt.title('Stacked Bar Plot')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.show()

# %% [markdown]
# ### Historgram

# %%
# random floats sampled from a univariate “normal” (Gaussian) 
# distribution of mean 0 and variance 1
X = np.random.randn(100)

plt.hist(X, bins=100)  # bins - the number to divide the data by
plt.title('Histogram')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.show()

# %% [markdown]
# ### Boxplot

# %%
data = np.random.randn(100, 6)

plt.boxplot(data)
plt.title('Boxplot')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.show()

# %% [markdown]
# ## Matplotlib with Pandas (Use-case)
# * Pandas as the well known library in python for data manipulation
# * Allows representation as dataframe, series that can be plotted

# %%
import pandas as pd

# %%
data_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/housing/housing.data'
df_data = pd.read_csv(data_url, sep='\s+', header=None)
df_data.columns = [
    'CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
    'PTRATIO', 'B', 'LSTAT', 'MEDV'
]

# %%
# A quick look of the dataset
df_data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX  ...    TAX  PTRATIO       B  LSTAT  MEDV
# 0  0.00632  18.0   2.31     0  0.538  ...  296.0     15.3  396.90   4.98  24.0
# 1  0.02731   0.0   7.07     0  0.469  ...  242.0     17.8  396.90   9.14  21.6
# 2  0.02729   0.0   7.07     0  0.469  ...  242.0     17.8  392.83   4.03  34.7
# 3  0.03237   0.0   2.18     0  0.458  ...  222.0     18.7  394.63   2.94  33.4
# 4  0.06905   0.0   2.18     0  0.458  ...  222.0     18.7  396.90   5.33  36.2
#
# [5 rows x 14 columns]

# %% [markdown]
# ### Scatter graph

# %%
fig = plt.figure() # Reset our figure
ax = []

for i in range(1, 5):
    ax.append(fig.add_subplot(2, 2, i))  # We have four plots

ax[0].scatter(df_data["CRIM"], df_data["MEDV"])
ax[1].scatter(df_data["PTRATIO"], df_data["MEDV"])
ax[2].scatter(df_data["AGE"], df_data["MEDV"])
ax[3].scatter(df_data["NOX"], df_data["MEDV"])
plt.show()

# %% [markdown]
# Its not exactly clear, so lets apply the axis and legends that we learned earlier.

# %%
fig = plt.figure()
fig.set_size_inches(10.0, 10.0, forward=True)
ax = []

for i in range(1, 5):
    ax.append(fig.add_subplot(2, 2, i))

columns = ["CRIM", "PTRATIO", "AGE", "NOX"]
colors = ["b", "g", "c", "r"]

for i in range(4):
    ax[i].scatter(df_data[columns[i]],
                  df_data["MEDV"],
                  color=colors[i],
                  label=columns[i])
    ax[i].legend()
    ax[i].set_title(columns[i])

plt.subplots_adjust(wspace=0, hspace=0)
plt.show()

# %% [markdown]
# Lets plot all the data we have now

# %%
df_data.plot()
plt.show()

# %% [markdown]
# Similarly, we can plot the data in histogram

# %%
fig = plt.figure()
fig.set_size_inches(10, 5)

ax_1 = fig.add_subplot(1, 2, 1)
ax_2 = fig.add_subplot(1, 2, 2)

ax_1.plot(df_data["MEDV"])
ax_2.hist(df_data["MEDV"], bins=50)

ax_1.set_title("House price MEDV")
ax_2.set_title("House price MEDV")

plt.show()

# %% [markdown]
# Likewise in the form of scatter matrix that allows mapping the correlation of all data.
#
# The diagonal of each matrix shows the distribution

# %%
pd.plotting.scatter_matrix(df_data, diagonal="kde", alpha=1, figsize=(20, 20))
plt.show()
